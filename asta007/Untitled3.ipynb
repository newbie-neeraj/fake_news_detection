# %%
from os import listdir
from os.path import isfile, join

# %%
path="C:\dataset"
onlyfiles = [f for f in listdir(path) if isfile(join(path, f))]
print(onlyfiles)
# Out:
# ['articles_1.xlsx', 'articles_2.xlsx', 'articles_3.xlsx', 'real_news.xlsx']

# %%
import xlsxwriter

# %%
import pandas as pd

# %%
df_real_1eal_1=pd.read_excel(path+"\\articles_1.xlsx")

# %%
df_real_1.head(5)
# Out:
#    url Unnamed: 1     id                                              title  \
# 0  NaN          0  17283  House Republicans Fret About Winning Their Hea...
# 1  NaN          1  17284  Rift Between Officers and Residents as Killing...
# 2  NaN          2  17285  Tyrus Wong, â€˜Bambiâ€™ Artist Thwarted by Rac...
# 3  NaN          3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4  NaN          4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author                 date  year  \
# 0  New York Times                     Carl Hulse  2016-12-31 00:00:00  2016
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19 00:00:00  2017
# 2  New York Times                   Margalit Fox  2017-01-06 00:00:00  2017
# 3  New York Times               William McDonald  2017-04-10 00:00:00  2017
# 4  New York Times                  Choe Sang-Hun  2017-01-02 00:00:00  2017
#
# ...

# %%
df_real_1.size
# Out:
# 42955200

# %%
df_real_1.shape
# Out:
# (50240, 855)

# %%
delete_cols=["url","id","publication","author","date","year","month"]
df_real_1.drop(delete_cols,axis=True,inplace=True)

# %%
df_real_1.head(5)
# Out:
#   Unnamed: 1                                              title  \
# 0          0  House Republicans Fret About Winning Their Hea...
# 1          1  Rift Between Officers and Residents as Killing...
# 2          2  Tyrus Wong, â€˜Bambiâ€™ Artist Thwarted by Rac...
# 3          3  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4          4  Kim Jong-un Says North Korea Is Preparing to T...
#
#                                              content Unnamed: 10 Unnamed: 11  \
# 0  WASHINGTON  â€”   Congressional Republicans ha...         NaN         NaN
# 1  After the bullet shells get counted, the blood...         NaN         NaN
# 2  When Walt Disneyâ€™s â€œBambiâ€ opened in 194...         NaN         NaN
# 3  Death may be the great equalizer, but it isnâ€...         NaN         NaN
# 4  SEOUL, South Korea  â€”   North Koreaâ€™s lead...         NaN         NaN
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  ...  \
# ...

# %%
writer = pd.ExcelWriter('real.xlsx', engine='xlsxwriter')

# %%
df_real_1.to_excel(writer, sheet_name='Sheet1')

# %%
writer = pd.ExcelWriter(path+"\\real.xlsx", engine='xlsxwriter')

# %%
df_real_1.to_excel(writer, sheet_name='Sheet1')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-729fe4ce2212> in <module>
# ----> 1 df_real_1.to_excel(writer, sheet_name='Sheet1')
#
# D:\SETUP_FILES_2\Anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2254             startcol=startcol,
#    2255             freeze_panes=freeze_panes,
# -> 2256             engine=engine,
#    2257         )
#    2258
#
# D:\SETUP_FILES_2\Anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     737             startrow=startrow,
#     738             startcol=startcol,
# --> 739             freeze_panes=freeze_panes,
#     740         )
# ...
